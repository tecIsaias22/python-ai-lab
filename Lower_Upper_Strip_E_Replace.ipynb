# %% [markdown]
# Inicial = "ISAias CAAETano Da SILva <br>"
# Final = "Isaias caetano da silva"

# %%
Texto = "ISAias CAETano Da SILva"

# %%
print(Texto)   # Imprime o texto original
# Out:
# ISAias CAETano Da SILva

# %%
print(Texto.lower())  # Converte para minúsculas
# Out:
# isaias caetano da silva

# %%
print(Texto.upper())  # Converte para maiúsculas
# Out:
# ISAIAS CAETANO DA SILVA

# %%
print(Texto.strip())  # Remove espaços em branco no início e no final
# Out:
# ISAias CAETano Da SILva

# %%
print(Texto.replace("SILVA1", "SILVA2"))  # Substitui "SILVA1" por "SILVA2"
# Out:
# ISAias CAETano Da SILva

# %%
print(Texto.strip().upper().replace("  ", " "))
# Out:
# ISAIAS CAETANO DA SILVA

# %%
Texto = Texto.strip().upper().replace("  ", " ")
print(Texto)
# Out:
# ISAIAS CAETANO DA SILVA

# %%
print(Texto)
