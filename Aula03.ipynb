# %%
Amigos = 5
Aluguel = 1000
SuperMercado = 200
Carro = 300

# %%
Total = Aluguel + SuperMercado + Carro

# %%
print(Total)
# Out:
# 1500

# %%
Aluguel = 900
Total = Aluguel + SuperMercado + Carro

# %%
print(Total)
# Out:
# 1400

# %%
Aluguel = Aluguel - 100

# %%
Amigos = 6
Aluguel = 1000
SuperMercado = 500
Carro = 400

# %%
print(Amigos)
# Out:
# 6

# %%
print(Carro * 2)
# Out:
# 800

# %%
Total_De_Carro = Carro * 2

# %%
print(Total_De_Carro)
# Out:
# 800

# %%
Total = Aluguel + SuperMercado + Total_De_Carro
print(Total)
# Out:
# 2300

# %%
Total_Por_Amigo = Total / Amigos
print(Total_Por_Amigo)
# Out:
# 383.3333333333333

# %%
type(Total_Por_Amigo)
# Out:
# float

# %%
type(Aluguel)
# Out:
# int

# %%
Isaias_Tem_Carteira_de_Motorista = True
Pedro_Tem_Carteira_de_Motorista = False

# %%
type(Pedro_Tem_Carteira_de_Motorista)
# Out:
# bool
