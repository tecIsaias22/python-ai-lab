# %%
nome = input("Digite seu nome: ")

# %%
print(nome)
# Out:
# isaias

# %%
idade = int(input("Digite sua idade: "))

# %%
print(idade)
# Out:
# 23

# %%
type(nome)
# Out:
# str

# %%
type(idade)
# Out:
# int

# %%
print("A pessoas se chama", nome, "e tem", idade, "anos.")
# Out:
# A pessoas se chama isaias e tem 23 anos.
