# %%
produto = 5

# %%
produto
# Out:
# 5

# %%
print(produto)
# Out:
# 5

# %%
produto1 = 2000

# %%
print(produto1)
# Out:
# 2000

# %%
produto2 = 1

# %%
print(produto + produto1 + produto2)
# Out:
# 2006

# %%
Nome_Do_Produto = "Nescau"
Nome_Do_Produto1 = "Celular"
Nome_Do_Produto2 = "Notebook"

# %%
print(Nome_Do_Produto + ", " + Nome_Do_Produto1 + ", " + Nome_Do_Produto2)
# Out:
# Nescau, Celular, Notebook
