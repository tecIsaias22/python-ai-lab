# %% [markdown]
# <a href="https://colab.research.google.com/github/tecIsaias22/python/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# començando a aula de python 01

# %%
5
# Out:
# 5

# %%
print("ola mundo e isaias")
# Out:
# ola mundo e isaias

# %%
print(4)
# Out:
# 4

# %%
print("ola mundo e isaias " + "5")
# Out:
# ola mundo e isaias 5
